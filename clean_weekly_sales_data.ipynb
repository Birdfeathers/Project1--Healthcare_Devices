# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path

# %%
sales_weekly_csv = Path('Resources/salesweekly.csv')

sales_weekly_df = pd.read_csv(sales_weekly_csv)

# %%
display(sales_weekly_df)
# Out:
#           datum  M01AB   M01AE  N02BA    N02BE  N05B  N05C        R03    R06
# 0      1/5/2014  14.00  11.670  21.30  185.950  41.0   0.0  32.000000   7.00
# 1     1/12/2014  29.33  12.680  37.90  190.700  88.0   5.0  21.000000   7.20
# 2     1/19/2014  30.67  26.340  45.90  218.400  80.0   8.0  29.000000  12.00
# 3     1/26/2014  34.00  32.370  31.50  179.600  80.0   8.0  23.000000  10.00
# 4      2/2/2014  31.02  23.350  20.70  159.880  84.0  12.0  29.000000  12.00
# ..          ...    ...     ...    ...      ...   ...   ...        ...    ...
# 297   9/15/2019  35.51  30.977  19.65  178.375  67.2   5.0  30.000000  30.50
# 298   9/22/2019  46.84  25.396  24.40  248.250  31.2   3.0  26.000000  21.00
# 299   9/29/2019  34.01  22.498  26.60  336.700  61.2   1.0  40.416667  23.10
# 300   10/6/2019  38.70  32.502  19.25  249.450  69.0   5.0  30.000000  12.13
# 301  10/13/2019   7.67   6.237   3.50   95.100  26.0   2.0  12.000000   1.00
#
# [302 rows x 9 columns]

# %%
print(sales_weekly_df.dtypes)
# Out:
# datum     object
# M01AB    float64
# M01AE    float64
# N02BA    float64
# N02BE    float64
# N05B     float64
# N05C     float64
# R03      float64
# R06      float64
# dtype: object

# %%
clean_sales_weekly_df = sales_weekly_df.dropna()
clean_sales_weekly_df
# Out:
#           datum  M01AB   M01AE  N02BA    N02BE  N05B  N05C        R03    R06
# 0      1/5/2014  14.00  11.670  21.30  185.950  41.0   0.0  32.000000   7.00
# 1     1/12/2014  29.33  12.680  37.90  190.700  88.0   5.0  21.000000   7.20
# 2     1/19/2014  30.67  26.340  45.90  218.400  80.0   8.0  29.000000  12.00
# 3     1/26/2014  34.00  32.370  31.50  179.600  80.0   8.0  23.000000  10.00
# 4      2/2/2014  31.02  23.350  20.70  159.880  84.0  12.0  29.000000  12.00
# ..          ...    ...     ...    ...      ...   ...   ...        ...    ...
# 297   9/15/2019  35.51  30.977  19.65  178.375  67.2   5.0  30.000000  30.50
# 298   9/22/2019  46.84  25.396  24.40  248.250  31.2   3.0  26.000000  21.00
# 299   9/29/2019  34.01  22.498  26.60  336.700  61.2   1.0  40.416667  23.10
# 300   10/6/2019  38.70  32.502  19.25  249.450  69.0   5.0  30.000000  12.13
# 301  10/13/2019   7.67   6.237   3.50   95.100  26.0   2.0  12.000000   1.00
#
# [302 rows x 9 columns]

# %%
clean_sales_weekly_df = clean_sales_weekly_df.rename(columns={
                                        'datum':'Date',
                                        'M01AB': 'Acetic Acid Derivatives',
                                        'M01AE': 'Propionic Acid Derivatives',
                                        'N02BA': 'Salicylic Acid and Derivatives',
                                        'N02BE': 'Pyrazolones and Anilides',
                                        'N05B': 'Anxiolytic Drugs',
                                        'N05C': 'Hypnotics and Sedatives Drugs',
                                        'R03': 'Drugs for Obstructive Airway Diseases',
                                        'R06': 'Antihistamines for systemic use'})

clean_sales_weekly_df.head()
# Out:
#         Date  Acetic Acid Derivatives  Propionic Acid Derivatives  \
# 0   1/5/2014                    14.00                       11.67
# 1  1/12/2014                    29.33                       12.68
# 2  1/19/2014                    30.67                       26.34
# 3  1/26/2014                    34.00                       32.37
# 4   2/2/2014                    31.02                       23.35
#
#    Salicylic Acid and Derivatives  Pyrazolones and Anilides  Anxiolytic Drugs  \
# 0                            21.3                    185.95              41.0
# 1                            37.9                    190.70              88.0
# 2                            45.9                    218.40              80.0
# 3                            31.5                    179.60              80.0
# 4                            20.7                    159.88              84.0
#
#    Hypnotics and Sedatives Drugs  Drugs for Obstructive Airway Diseases  \
# ...

# %%
clean_sales_weekly_df['Date'] = pd.to_datetime(clean_sales_weekly_df['Date'])
print(clean_sales_weekly_df.dtypes)
clean_sales_weekly_df.head()
# Out:
# Date                                     datetime64[ns]
# Acetic Acid Derivatives                         float64
# Propionic Acid Derivatives                      float64
# Salicylic Acid and Derivatives                  float64
# Pyrazolones and Anilides                        float64
# Anxiolytic Drugs                                float64
# Hypnotics and Sedatives Drugs                   float64
# Drugs for Obstructive Airway Diseases           float64
# Antihistamines for systemic use                 float64
# dtype: object
#         Date  Acetic Acid Derivatives  Propionic Acid Derivatives  \
# 0 2014-01-05                    14.00                       11.67
# 1 2014-01-12                    29.33                       12.68
# 2 2014-01-19                    30.67                       26.34
# 3 2014-01-26                    34.00                       32.37
# 4 2014-02-02                    31.02                       23.35
#
# ...

# %%
clean_sales_weekly_df = clean_sales_weekly_df.set_index('Date')
clean_sales_weekly_df.plot(ylabel='Sales Volume')
plt.legend(bbox_to_anchor=(1.05, 1))
plt.show()

# %%
clean_sales_weekly_df['total'] = clean_sales_weekly_df[clean_sales_weekly_df.columns].sum(axis = 1)

# %%
clean_sales_weekly_df.plot(ylabel='Sales Volume')
# Out:
# <Axes: xlabel='Date', ylabel='Sales Volume'>

# %%
# %store clean_sales_weekly_df
# Out:
# Stored 'clean_sales_weekly_df' (DataFrame)
